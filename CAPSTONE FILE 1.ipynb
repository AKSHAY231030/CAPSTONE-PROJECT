# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.makaan.com/mumbai-residential-property/buy-property-in-mumbai-city"

# %%
response = requests.post(
       url="https://www.makaan.com/mumbai-residential-property/buy-property-in-mumbai-city",
       auth=(USERNAME, PASSWORD),
       json=payload,
)
print(response.status_code)
# Out:
# 200

# %%
response.raise_for_status()

# %%
soup = BeautifulSoup(r.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
listings = soup.find_all("div", {"class": "homecardV2"})

# %%
data = []
for listing in soup.find_all("div", {"class": "bottomV2"}):
	...

# %%
def extract_data_from_listing(listing):
	...

# %%
listings = soup.find_all("div", {"class": "homecardV2"})

# %%
price = listing.find("span", {"class": "homecardV2Price"}).get_text(strip=True)
address = listing.find("span", {"class": "collapsedAddress"}).get_text(strip=True)

# %%
stats = listing.find_all("div", {"class":"stats"})
try:
    bed_count_elem, bath_count_elem, size_elem = stats[0], stats[1], stats[2]
except IndexError:
    raise Exception("Got less stats than expected")

bed_count = bed_count_elem.get_text(strip=True)
bath_count = bath_count_elem.get_text(strip=True)
size = size_elem.get_text(strip=True)

# %%
entry = {
    "price": price,
    "address": address,
    "bed_count": bed_count,
    "bath_count": bath_count,
    "size": size,
}
data.append(entry)

# %%
def extract_data_from_listing(listing):
    price = listing.find("span", {"class": "homecardV2Price"}).get_text(strip=True)
    address = listing.find("span", {"class": "collapsedAddress"}).get_text(strip=True)
    stats = listing.find_all("div", {"class": "stats"})
    try:
        bed_count_elem, bath_count_elem, size_elem = stats[0], stats[1], stats[2]
    except IndexError:
        raise Exception("Got less stats than expected")

    bed_count = bed_count_elem.get_text(strip=True)
    bath_count = bath_count_elem.get_text(strip=True)
    size = size_elem.get_text(strip=True)

    return {
        "price": price,
        "address": address,
        "bed_count": bed_count,
        "bath_count": bath_count,
        "size": size,
    }


data = []

for listing in soup.find_all("div", {"class": "bottomV2"}):
    entry = extract_data_from_listing(listing)
    data.append(entry)

# %%
df = pd.DataFrame(data)
df.to_csv("real_estate_data.csv")

# %%
PHASE 2

# %%
import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
import pandas as pd

table1 = pd.read_csv('Table1.csv')
table2 = pd.read_csv('Table2.csv')
table3 = pd.read_csv('Table3.csv')

# %%
merged_table12 = pd.merge(table1, table2, on='Sno')

merged_table = pd.merge(merged_table12, table3, on='Sno')

# %%
properties = [
    {'id': 1, 'balcony': True, 'num_bedrooms': 3, 'num_bathrooms': 2, 'city': 'New York', 'state': 'New York', 'landmark': 'park'},
    {'id': 2, 'balcony': False, 'num_bedrooms': 2, 'num_bathrooms': 1, 'city': 'Los Angeles', 'state': 'California', 'landmark': 'beach'},
    {'id': 3, 'balcony': True, 'num_bedrooms': 4, 'num_bathrooms': 3, 'city': 'New York', 'state': 'New York', 'landmark': 'park'},
    {'id': 4, 'balcony': True, 'num_bedrooms': 3, 'num_bathrooms': 2, 'city': 'Chicago', 'state': 'Illinois', 'landmark': 'lake'},
    {'id': 5, 'balcony': False, 'num_bedrooms': 2, 'num_bathrooms': 1, 'city': 'Los Angeles', 'state': 'California', 'landmark': 'beach'},
    # ...
]

# %%
properties_with_balconies = [prop for prop in properties if prop['balcony']]
properties_with_balconies.sort(key=lambda x: x['num_bedrooms'], reverse=True)
print(properties_with_balconies)

# %%
from collections import defaultdict

city_bedrooms = defaultdict(list)
for prop in properties:
    city_bedrooms[prop['city']].append(prop['num_bedrooms'])

avg_bedrooms_per_city = {city: sum(bedrooms) / len(bedrooms) for city, bedrooms in city_bedrooms.items()}
top_5_cities = sorted(avg_bedrooms_per_city.items(), key=lambda x: x[1], reverse=True)[:5]
print(top_5_cities)

# %%
from collections import defaultdict

city_properties = defaultdict(int)
for prop in properties:
    city_properties[prop['city']] += 1
print(dict(city_properties))

# %%
properties_with_3_bedrooms_2_bathrooms = [prop for prop in properties if prop['num_bedrooms'] >= 3 and prop['num_bathrooms'] >= 2]
print(properties_with_3_bedrooms_2_bathrooms)

# %%
properties_in_california_with_beach = [prop for prop in properties if prop['state'] == 'California' and prop['landmark'] == 'beach']
print(properties_in_california_with_beach)

# %%
1- Calculate the average price per square foot for properties built before 2010.

2- Find the total number of properties on each floor.

3- Retrieve properties with a carpet area greater than 1000 square feet and a status of 'Under Construction'.

4- Calculate the average price per square foot for each transaction type.

5- Find the properties with the highest price per square foot, sorted in descending order.

# %%
python
properties_before_2010 = [prop for prop in properties if prop['built_year'] < 2010]
avg_price_per_sqft = sum(prop['price_per_sqft'] for prop in properties_before_2010) / len(properties_before_2010)
print(avg_price_per_sqft)

# %%
python
from collections import defaultdict

floor_properties = defaultdict(int)
for prop in properties:
    floor_properties[prop['floor']] += 1
print(dict(floor_properties))

# %%
python
properties_with_large_carpet_area = [prop for prop in properties if prop['carpet_area'] > 1000 and prop['status'] == 'Under Construction']
print(properties_with_large_carpet_area)

# %%
python
from collections import defaultdict

transaction_type_prices = defaultdict(list)
for prop in properties:
    transaction_type_prices[prop['transaction_type']].append(prop['price_per_sqft'])

avg_price_per_sqft_per_transaction_type = {transaction_type: sum(prices) / len(prices) for transaction_type, prices in transaction_type_prices.items()}
print(avg_price_per_sqft_per_transaction_type)

# %%
python
properties.sort(key=lambda x: x['price_per_sqft'], reverse=True)
print(properties)

# %%
properties = [
    {'id': 1, 'furnished_status': 'Fully Furnished', 'facing_direction': 'East', 'booking_amount': 20000, 'ownership_type': 'Freehold', 'car_parking': True},
    {'id': 2, 'furnished_status': 'Semi Furnished', 'facing_direction': 'West', 'booking_amount': 30000, 'ownership_type': 'Leasehold', 'car_parking': False},
    {'id': 3, 'furnished_status': 'Fully Furnished', 'facing_direction': 'East', 'booking_amount': 40000, 'ownership_type': 'Freehold', 'car_parking': True},
    {'id': 4, 'furnished_status': 'Unfurnished', 'facing_direction': 'North', 'booking_amount': 50000, 'ownership_type': 'Leasehold', 'car_parking': False},
    # ...
]

# %%
python
properties_with_fully_furnished_east_facing = [prop for prop in properties if prop['furnished_status'] == 'Fully Furnished' and prop['facing_direction'] == 'East']
print(properties_with_fully_furnished_east_facing)

# %%
python
properties_with_car_parking = [prop for prop in properties if prop['car_parking']]
properties_without_car_parking = [prop for prop in properties if not prop['car_parking']]

avg_booking_amount_with_car_parking = sum(prop['booking_amount'] for prop in properties_with_car_parking) / len(properties_with_car_parking)
avg_booking_amount_without_car_parking = sum(prop['booking_amount'] for prop in properties_without_car_parking) / len(properties_without_car_parking)

print('Average booking amount with car parking:', avg_booking_amount_with_car_parking)
print('Average booking amount without car parking:', avg_booking_amount_without_car_parking)

# %%
python
from collections import defaultdict

ownership_type_prices = defaultdict(int)
for prop in properties:
    ownership_type_prices[prop['ownership_type']] += prop['booking_amount']

print(dict(ownership_type_prices))

# %%
python
property_with_highest_booking_amount = max(properties, key=lambda x: x['booking_amount'])
print(property_with_highest_booking_amount)

# %%
import sqlite3

# %%
conn = sqlite3.connect('database.db')
cursor = conn.cursor()

# %%
cursor.execute("""
    SELECT *
    FROM table1
    WHERE price_per_sqft > (SELECT AVG(price_per_sqft) FROM table2)
""")
result1 = cursor.fetchall()
print("Properties with higher price per square foot than average:")
for row in result1:
    print(row)

# %%
cursor.execute("""
    SELECT *
    FROM table1
    WHERE city IN (
        SELECT city
        FROM table2
        GROUP BY city
        HAVING AVG(price_per_sqft) > (SELECT AVG(price_per_sqft) FROM table2)
    )
""")
result2 = cursor.fetchall()
print("\nProperties in cities with higher average price per square foot:")
for row in result2:
    print(row)

# %%
cursor.execute("""
    SELECT *
    FROM table1
    WHERE landmark = 'Park' AND price_per_sqft < (
        SELECT AVG(price_per_sqft)
        FROM table2
        WHERE city IN (
            SELECT city
            FROM table1
